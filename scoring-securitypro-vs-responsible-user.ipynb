# %%
# Config Section: inital values, constants, libraries etc

import math
from datetime import date, datetime
from dateutil import parser

import plotly
plotly.tools.set_credentials_file(username='pmoolrajani', api_key='lqy9gutcnu')
import plotly.plotly as py
from plotly.graph_objs import *
import plotly.graph_objs as go

# setting constants
__EVENT_TYPES = {
    'incidents':{'risk': 0.5, 'sla':3},
    'patching':{'risk': 0.3, 'sla': 7},
    'misc':{'risk': 0.2, 'sla': 5}
}
__SCORE_MAX = 1000
__SCORE_MIN = 0
__NO_EVENTS_FRACTION = 0.90
__TIME_INTERVAL = 7
__NUM_DAYS = 30


# setting initial values
score_avg_company = 620
score_emp = score_avg_company
risk = 0.5

# %%
# Logic Section - security pro

# setting initial values
score_avg_company = 620
score_emp = score_avg_company


# creating dictionary of events from the input csv file
dict_events = {}
file_events = open('data/scoring-security-pro-user.csv').readlines()


dict_events = {}
for line in file_events:
    
    event_details = line.split(',')
    if event_details[0] != 'event_date':
        event_date = parser.parse(event_details[0].strip())
        event_type = event_details[1].strip()
        num_events_recv = event_details[2].strip()
        num_events_resp = event_details[3].strip()
        num_events_sla_breach = event_details[4].strip()

        dict_events[event_date] = {}
        dict_events[event_date]['event_type'] = event_type
        dict_events[event_date]['num_events_recv'] = int(num_events_recv)
        dict_events[event_date]['num_events_resp'] = int(num_events_resp)
        dict_events[event_date]['num_events_sla_breach'] = int(num_events_sla_breach)
        

dict_scores = {}
for i in range(1, __NUM_DAYS, __TIME_INTERVAL):
    
    # calculating confidence intervals for employee score
    cpos = math.sqrt(__SCORE_MAX - score_emp)
    cneg = math.sqrt(score_emp)

    # calculating upper and lower limit of security score of an employee for __TIME_INTERVAL
    score_cpos = score_emp + cpos
    score_cneg = score_emp - cneg
    
    print ('\n\n')
    print ('TIME_INTERVAL: '+str(datetime(2016, 8, i, 0, 0)))
    print ('SCORE: '+str(score_emp))
    print ('C+ve: '+str(score_cpos)+'  |  '+'C-ve: '+str(score_cneg))
    print ('')
    no_events_counter = 0
    for j in range(i, i + __TIME_INTERVAL):
        if j > 31:
            break
            
        date_counter = datetime(2016, 8, j, 0, 0)
        
        if dict_events[date_counter]['num_events_recv'] == 0:
            
            print ('#days_left: '+str(__TIME_INTERVAL - (j-i)))
            print ('#numerator: '+str(score_cpos - score_emp))
            
            score_emp += (score_cpos - score_emp)*__NO_EVENTS_FRACTION/(__TIME_INTERVAL - (j-i))
        
        print ('\t'+str(date_counter))
        print ('\t\t'+'score_before: '+str(score_emp))
        print ('\t\t'+'events: '+'resp - '+str(dict_events[date_counter]['num_events_resp'])\
               +', recv - '+str(dict_events[date_counter]['num_events_recv'])\
               +', sla_breach - '+str(dict_events[date_counter]['num_events_sla_breach'])) 
        
        for k in range(0, dict_events[date_counter]['num_events_resp']):
            score_emp = score_emp + (score_cpos - score_emp)*(risk)
        for k in range(0, dict_events[date_counter]['num_events_sla_breach']):
            score_emp = score_emp - (score_emp - score_cneg)*(risk)
        
        print ('\t\t'+'score_after: '+str(score_emp))
        
        dict_scores[date_counter] = score_emp
        
# plotting score on graph
x_axis = []
y_axis = []
for day in dict_scores:
    x_axis.append(str(day))
    y_axis.append(dict_scores[day])
trace0 = go.Bar(x=x_axis, y=y_axis)
# Out:
# TIME_INTERVAL: 2016-08-01 00:00:00
# SCORE: 620
# C+ve: 639.4935886896179  |  C-ve: 595.1002008040225
#
# #days_left: 7
# #numerator: 19.493588689617923
# 	2016-08-01 00:00:00
# 		score_before: 622.506318545808
# 		events: resp - 0, recv - 0, sla_breach - 0
# 		score_after: 622.506318545808
# #days_left: 6
# #numerator: 16.98727014380995
# 	2016-08-02 00:00:00
# 		score_before: 625.0544090673794
# 		events: resp - 0, recv - 0, sla_breach - 0
# 		score_after: 625.0544090673794
# #days_left: 5
# #numerator: 14.439179622238498
# 	2016-08-03 00:00:00
# 		score_before: 627.6534613993823
# 		events: resp - 0, recv - 0, sla_breach - 0
# 		score_after: 627.6534613993823
# #days_left: 4
# #numerator: 11.840127290235614
# 	2016-08-04 00:00:00
# 		score_before: 630.3174900396854
# 		events: resp - 0, recv - 0, sla_breach - 0
# 		score_after: 630.3174900396854
# #days_left: 3
# #numerator: 9.176098649932555
# 	2016-08-05 00:00:00
# 		score_before: 633.0703196346651
# 		events: resp - 0, recv - 0, sla_breach - 0
# 		score_after: 633.0703196346651
# #days_left: 2
# #numerator: 6.4232690549528115
# 	2016-08-06 00:00:00
# 		score_before: 635.9607907093939
# 		events: resp - 0, recv - 0, sla_breach - 0
# 		score_after: 635.9607907093939
# #days_left: 1
# #numerator: 3.532797980224018
# 	2016-08-07 00:00:00
# 		score_before: 639.1403088915955
# 		events: resp - 0, recv - 0, sla_breach - 0
# 		score_after: 639.1403088915955
#
#
#
# TIME_INTERVAL: 2016-08-08 00:00:00
# SCORE: 639.1403088915955
# C+ve: 658.1366161935003  |  C-ve: 613.8590844574112
#
# #days_left: 7
# #numerator: 18.996307301904835
# 	2016-08-08 00:00:00
# 		score_before: 641.5826912589832
# 		events: resp - 0, recv - 0, sla_breach - 0
# 		score_after: 641.5826912589832
# #days_left: 6
# #numerator: 16.553924934517113
# 	2016-08-09 00:00:00
# 		score_before: 644.0657799991608
# 		events: resp - 0, recv - 0, sla_breach - 0
# 		score_after: 644.0657799991608
# #days_left: 5
# #numerator: 14.070836194339563
# 	2016-08-10 00:00:00
# 		score_before: 646.5985305141419
# 		events: resp - 0, recv - 0, sla_breach - 0
# 		score_after: 646.5985305141419
# #days_left: 4
# #numerator: 11.53808567935846
# 	2016-08-11 00:00:00
# 		score_before: 649.1945997919976
# 		events: resp - 0, recv - 0, sla_breach - 0
# 		score_after: 649.1945997919976
# #days_left: 3
# #numerator: 8.94201640150277
# 	2016-08-12 00:00:00
# 		score_before: 651.8772047124484
# 		events: resp - 0, recv - 0, sla_breach - 0
# 		score_after: 651.8772047124484
# #days_left: 2
# #numerator: 6.259411481051984
# 	2016-08-13 00:00:00
# 		score_before: 654.6939398789218
# 		events: resp - 0, recv - 0, sla_breach - 0
# 		score_after: 654.6939398789218
# #days_left: 1
# #numerator: 3.4426763145785344
# 	2016-08-14 00:00:00
# 		score_before: 657.7923485620424
# 		events: resp - 0, recv - 0, sla_breach - 0
# 		score_after: 657.7923485620424
#
#
#
# TIME_INTERVAL: 2016-08-15 00:00:00
# SCORE: 657.7923485620424
# C+ve: 676.2912039709038  |  C-ve: 632.144885752594
#
# #days_left: 7
# #numerator: 18.498855408861345
# 	2016-08-15 00:00:00
# 		score_before: 660.170772828896
# 		events: resp - 0, recv - 0, sla_breach - 0
# 		score_after: 660.170772828896
# #days_left: 6
# #numerator: 16.12043114200776
# 	2016-08-16 00:00:00
# 		score_before: 662.5888375001972
# 		events: resp - 0, recv - 0, sla_breach - 0
# 		score_after: 662.5888375001972
# #days_left: 5
# #numerator: 13.702366470706579
# 	2016-08-17 00:00:00
# 		score_before: 665.0552634649243
# 		events: resp - 0, recv - 0, sla_breach - 0
# 		score_after: 665.0552634649243
# #days_left: 4
# #numerator: 11.235940505979443
# 	2016-08-18 00:00:00
# 		score_before: 667.5833500787697
# 		events: resp - 0, recv - 0, sla_breach - 0
# 		score_after: 667.5833500787697
# #days_left: 3
# #numerator: 8.70785389213404
# 	2016-08-19 00:00:00
# 		score_before: 670.1957062464099
# 		events: resp - 0, recv - 0, sla_breach - 0
# 		score_after: 670.1957062464099
# #days_left: 2
# #numerator: 6.095497724493839
# 	2016-08-20 00:00:00
# 		score_before: 672.9386802224321
# 		events: resp - 0, recv - 0, sla_breach - 0
# 		score_after: 672.9386802224321
# #days_left: 1
# #numerator: 3.35252374847164
# 	2016-08-21 00:00:00
# 		score_before: 675.9559515960566
# 		events: resp - 0, recv - 0, sla_breach - 0
# 		score_after: 675.9559515960566
#
#
#
# TIME_INTERVAL: 2016-08-22 00:00:00
# SCORE: 675.9559515960566
# C+ve: 693.9571751212491  |  C-ve: 649.9567986945474
#
# #days_left: 7
# #numerator: 18.001223525192472
# 	2016-08-22 00:00:00
# 		score_before: 678.2703946207242
# 		events: resp - 0, recv - 0, sla_breach - 0
# 		score_after: 678.2703946207242
# #days_left: 6
# #numerator: 15.686780500524833
# 	2016-08-23 00:00:00
# 		score_before: 680.6234116958029
# 		events: resp - 0, recv - 0, sla_breach - 0
# 		score_after: 680.6234116958029
# #days_left: 5
# #numerator: 13.333763425446136
# 	2016-08-24 00:00:00
# 		score_before: 683.0234891123832
# 		events: resp - 0, recv - 0, sla_breach - 0
# 		score_after: 683.0234891123832
# #days_left: 4
# #numerator: 10.933686008865834
# 	2016-08-25 00:00:00
# 		score_before: 685.4835684643781
# 		events: resp - 0, recv - 0, sla_breach - 0
# 		score_after: 685.4835684643781
# #days_left: 3
# #numerator: 8.47360665687097
# 	2016-08-26 00:00:00
# 		score_before: 688.0256504614393
# 		events: resp - 0, recv - 0, sla_breach - 0
# 		score_after: 688.0256504614393
# #days_left: 2
# #numerator: 5.931524659809725
# 	2016-08-27 00:00:00
# 		score_before: 690.6948365583537
# 		events: resp - 0, recv - 0, sla_breach - 0
# 		score_after: 690.6948365583537
# #days_left: 1
# #numerator: 3.2623385628953656
# 	2016-08-28 00:00:00
# 		score_before: 693.6309412649596
# 		events: resp - 0, recv - 0, sla_breach - 0
# 		score_after: 693.6309412649596
#
#
#
# TIME_INTERVAL: 2016-08-29 00:00:00
# SCORE: 693.6309412649596
# C+ve: 711.134342612556  |  C-ve: 667.2940670908105
#
# #days_left: 7
# #numerator: 17.503401347596423
# 	2016-08-29 00:00:00
# 		score_before: 695.8813785810792
# 		events: resp - 0, recv - 0, sla_breach - 0
# 		score_after: 695.8813785810792
# #days_left: 6
# #numerator: 15.252964031476836
# 	2016-08-30 00:00:00
# 		score_before: 698.1693231858006
# 		events: resp - 0, recv - 0, sla_breach - 0
# 		score_after: 698.1693231858006
# #days_left: 5
# #numerator: 12.965019426755362
# 	2016-08-31 00:00:00
# 		score_before: 700.5030266826166
# 		events: resp - 0, recv - 0, sla_breach - 0
# 		score_after: 700.5030266826166

# %%
# Logic Section - responsible user (responding within SLA)  

# setting initial values
score_avg_company = 620
score_emp = score_avg_company

# creating dictionary of events from the input csv file
dict_events = {}
file_events = open('data/scoring-normal-responsible-user.csv').readlines()


dict_events = {}
for line in file_events:
    
    event_details = line.split(',')
    if event_details[0] != 'event_date':
        event_date = parser.parse(event_details[0].strip())
        event_type = event_details[1].strip()
        num_events_recv = event_details[2].strip()
        num_events_resp = event_details[3].strip()
        num_events_sla_breach = event_details[4].strip()

        dict_events[event_date] = {}
        dict_events[event_date]['event_type'] = event_type
        dict_events[event_date]['num_events_recv'] = int(num_events_recv)
        dict_events[event_date]['num_events_resp'] = int(num_events_resp)
        dict_events[event_date]['num_events_sla_breach'] = int(num_events_sla_breach)
        

dict_scores = {}
for i in range(1, __NUM_DAYS, __TIME_INTERVAL):
    
    # calculating confidence intervals for employee score
    cpos = math.sqrt(__SCORE_MAX - score_emp)
    cneg = math.sqrt(score_emp)

    # calculating upper and lower limit of security score of an employee for __TIME_INTERVAL
    score_cpos = score_emp + cpos
    score_cneg = score_emp - cneg
    
    print ('\n\n')
    print ('TIME_INTERVAL: '+str(datetime(2016, 8, i, 0, 0)))
    print ('SCORE: '+str(score_emp))
    print ('C+ve: '+str(score_cpos)+'  |  '+'C-ve: '+str(score_cneg))
    print ('')
    no_events_counter = 0
    for j in range(i, i + __TIME_INTERVAL):
        if j > 31:
            break
            
        date_counter = datetime(2016, 8, j, 0, 0)
        
        if dict_events[date_counter]['num_events_recv'] == 0:
            
            #print ('#days_left: '+str(__TIME_INTERVAL - (j-i)))
            #print ('#numerator: '+str(score_cpos - score_emp))
            
            score_emp += (score_cpos - score_emp)*__NO_EVENTS_FRACTION/(__TIME_INTERVAL - (j-i))
        
        print ('\t'+str(date_counter))
        print ('\t\t'+'score_before: '+str(score_emp))
        print ('\t\t'+'events: '+'resp - '+str(dict_events[date_counter]['num_events_resp'])\
               +', recv - '+str(dict_events[date_counter]['num_events_recv'])\
               +', sla_breach - '+str(dict_events[date_counter]['num_events_sla_breach'])) 
        
        for k in range(0, dict_events[date_counter]['num_events_resp']):
            score_emp = score_emp + (score_cpos - score_emp)*(risk)
        for k in range(0, dict_events[date_counter]['num_events_sla_breach']):
            score_emp = score_emp - (score_emp - score_cneg)*(risk)
        
        print ('\t\t'+'score_after: '+str(score_emp))
        
        dict_scores[date_counter] = score_emp
        
# plotting score on graph
x_axis = []
y_axis = []
for day in dict_scores:
    x_axis.append(str(day))
    y_axis.append(dict_scores[day])
trace1 = go.Bar(x=x_axis, y=y_axis)
# Out:
# TIME_INTERVAL: 2016-08-01 00:00:00
# SCORE: 620
# C+ve: 639.4935886896179  |  C-ve: 595.1002008040225
#
# 	2016-08-01 00:00:00
# 		score_before: 620
# 		events: resp - 1, recv - 1, sla_breach - 0
# 		score_after: 629.7467943448089
# 	2016-08-02 00:00:00
# 		score_before: 629.7467943448089
# 		events: resp - 2, recv - 2, sla_breach - 0
# 		score_after: 637.0568901034158
# 	2016-08-03 00:00:00
# 		score_before: 637.4954958489321
# 		events: resp - 0, recv - 0, sla_breach - 0
# 		score_after: 637.4954958489321
# 	2016-08-04 00:00:00
# 		score_before: 637.9450667380864
# 		events: resp - 0, recv - 0, sla_breach - 0
# 		score_after: 637.9450667380864
# 	2016-08-05 00:00:00
# 		score_before: 638.4096233235459
# 		events: resp - 0, recv - 0, sla_breach - 0
# 		score_after: 638.4096233235459
# 	2016-08-06 00:00:00
# 		score_before: 638.4096233235459
# 		events: resp - 2, recv - 2, sla_breach - 0
# 		score_after: 639.2225973481
# 	2016-08-07 00:00:00
# 		score_before: 639.2225973481
# 		events: resp - 3, recv - 3, sla_breach - 0
# 		score_after: 639.4597147719282
#
#
#
# TIME_INTERVAL: 2016-08-08 00:00:00
# SCORE: 639.4597147719282
# C+ve: 658.4476131608515  |  C-ve: 614.1721740695996
#
# 	2016-08-08 00:00:00
# 		score_before: 639.4597147719282
# 		events: resp - 1, recv - 1, sla_breach - 0
# 		score_after: 648.9536639663899
# 	2016-08-09 00:00:00
# 		score_before: 648.9536639663899
# 		events: resp - 1, recv - 1, sla_breach - 0
# 		score_after: 653.7006385636207
# 	2016-08-10 00:00:00
# 		score_before: 653.7006385636207
# 		events: resp - 1, recv - 1, sla_breach - 0
# 		score_after: 656.0741258622361
# 	2016-08-11 00:00:00
# 		score_before: 656.0741258622361
# 		events: resp - 1, recv - 1, sla_breach - 0
# 		score_after: 657.2608695115438
# 	2016-08-12 00:00:00
# 		score_before: 657.2608695115438
# 		events: resp - 1, recv - 1, sla_breach - 0
# 		score_after: 657.8542413361977
# 	2016-08-13 00:00:00
# 		score_before: 657.8542413361977
# 		events: resp - 1, recv - 1, sla_breach - 0
# 		score_after: 658.1509272485246
# 	2016-08-14 00:00:00
# 		score_before: 658.1509272485246
# 		events: resp - 1, recv - 1, sla_breach - 0
# 		score_after: 658.299270204688
#
#
#
# TIME_INTERVAL: 2016-08-15 00:00:00
# SCORE: 658.299270204688
# C+ve: 676.7844191030689  |  C-ve: 632.6419268074326
#
# 	2016-08-15 00:00:00
# 		score_before: 658.299270204688
# 		events: resp - 3, recv - 3, sla_breach - 0
# 		score_after: 674.4737754907712
# 	2016-08-16 00:00:00
# 		score_before: 674.8203720326159
# 		events: resp - 0, recv - 0, sla_breach - 0
# 		score_after: 674.8203720326159
# 	2016-08-17 00:00:00
# 		score_before: 675.1739005052974
# 		events: resp - 0, recv - 0, sla_breach - 0
# 		score_after: 675.1739005052974
# 	2016-08-18 00:00:00
# 		score_before: 675.1739005052974
# 		events: resp - 1, recv - 1, sla_breach - 0
# 		score_after: 675.9791598041832
# 	2016-08-19 00:00:00
# 		score_before: 675.9791598041832
# 		events: resp - 1, recv - 1, sla_breach - 0
# 		score_after: 676.381789453626
# 	2016-08-20 00:00:00
# 		score_before: 676.381789453626
# 		events: resp - 1, recv - 1, sla_breach - 0
# 		score_after: 676.5831042783475
# 	2016-08-21 00:00:00
# 		score_before: 676.5831042783475
# 		events: resp - 1, recv - 1, sla_breach - 0
# 		score_after: 676.6837616907083
#
#
#
# TIME_INTERVAL: 2016-08-22 00:00:00
# SCORE: 676.6837616907083
# C+ve: 694.6647582790315  |  C-ve: 650.6706157508049
#
# 	2016-08-22 00:00:00
# 		score_before: 676.6837616907083
# 		events: resp - 1, recv - 1, sla_breach - 0
# 		score_after: 685.6742599848699
# 	2016-08-23 00:00:00
# 		score_before: 685.6742599848699
# 		events: resp - 2, recv - 2, sla_breach - 0
# 		score_after: 692.4171337054911
# 	2016-08-24 00:00:00
# 		score_before: 692.4171337054911
# 		events: resp - 2, recv - 2, sla_breach - 0
# 		score_after: 694.1028521356463
# 	2016-08-25 00:00:00
# 		score_before: 694.1028521356463
# 		events: resp - 2, recv - 2, sla_breach - 0
# 		score_after: 694.5242817431852
# 	2016-08-26 00:00:00
# 		score_before: 694.5242817431852
# 		events: resp - 2, recv - 2, sla_breach - 0
# 		score_after: 694.6296391450699
# 	2016-08-27 00:00:00
# 		score_before: 694.6454427553526
# 		events: resp - 0, recv - 0, sla_breach - 0
# 		score_after: 694.6454427553526
# 	2016-08-28 00:00:00
# 		score_before: 694.6628267266636
# 		events: resp - 0, recv - 0, sla_breach - 0
# 		score_after: 694.6628267266636
#
#
#
# TIME_INTERVAL: 2016-08-29 00:00:00
# SCORE: 694.6628267266636
# C+ve: 712.1367264995631  |  C-ve: 668.3063697051545
#
# 	2016-08-29 00:00:00
# 		score_before: 696.9094709831793
# 		events: resp - 0, recv - 0, sla_breach - 0
# 		score_after: 696.9094709831793
# 	2016-08-30 00:00:00
# 		score_before: 696.9094709831793
# 		events: resp - 1, recv - 1, sla_breach - 0
# 		score_after: 704.5230987413712
# 	2016-08-31 00:00:00
# 		score_before: 704.5230987413712
# 		events: resp - 2, recv - 2, sla_breach - 0
# 		score_after: 710.2333195600152

# %%
data = [trace0, trace1]

py.iplot(data, filename='scoring-normal')
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~pmoolrajani/17.embed" height="525px" width="100%"></iframe>
